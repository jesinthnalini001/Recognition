# %% [markdown]
# **Gesture Recognition**

# %% [markdown]
# In this project, I have to build a 3D Conv model that will be able to predict the 5 gestures correctly. Import the required libraries to get started.

# %%
import numpy as np
import os
import imageio
from skimage.transform import resize
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import os
os.environ['PYTHONHASHSEED']="30"
from google.colab import drive
drive.mount('/content/drive')
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K


data_dir = os.path.join('/content', 'drive', 'My Drive', 'Project_data')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# In this block, folder names from gogle drive are read for training and validation. Setting the batch_size here. The batch size are set in such a way that we can able to use the GPU in full capacity. We keep increasing the batch size until the machine throws an error.

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    #train_doc = np.random.permutation(open(path+'train.csv').readlines())
    #val_doc = np.random.permutation(open(path+'val.csv').readlines())
    train_doc = np.random.permutation(open('/content/drive/My Drive/Project_data/train.csv').readlines())
    val_doc = np.random.permutation(open('/content/drive/My Drive/Project_data/val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1 
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data(data_dir, ablation=None)
batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# **Generator**

# %% [markdown]
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, we are going to preprocess the images as we have images of 2 different dimensions as well as create a batch of video frames. We have to experiment with img_idx, y,z and normalization such that we get high accuracy.

# %%
# generator with augmentation for train data
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)
            
        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1
            
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    #image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    resized_im = resize(image, (y,z)) #imresize(image, size=(y,z))

                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
#/content/drive/My Drive/Project_data/
#Project_data/train
train_path = '/content/drive/My Drive/Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
val_path =  '/content/drive/My Drive/Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs

print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative 
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]

# %% [markdown]
# **Model**

# %% [markdown]
# Here we make the model using different functionalities that Keras provides. Remember to use Conv3D and MaxPooling3D and not Conv2D and Maxpooling2D for a 3D convolution model. You would want to use TimeDistributed while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers.convolutional import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# Performing several experiments to reach the max accuracy using Conv 3D

# %% [markdown]
# **Experiment 1**

# %%
# model = Sequential()
# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 2**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(256, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(3, 2, 2)))

# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 3**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 4**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 4**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 5**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 6**

# %%
# loss: 0.1388 - categorical_accuracy: 0.9539 - val_loss: 0.1661 - val_categorical_accuracy: 0.9297
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GlobalAveragePooling3D())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 7(TimeDistributed Conv2D + GRU)**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 8 (using TimeDistributed Conv2D + GRU)**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 9 (TimeDistributed Conv2D + Dense)**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(128, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(GlobalAveragePooling3D())
# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **Experiment 10 (TimeDistributed + ConvLSTM2D)**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Conv2D(16, (3,3), activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(
#     ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Dense(64, activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(GlobalAveragePooling2D())
# model.add(Dense(64, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# **FINAL MODEL**

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# We have written the model, the next step is to compile the model. When we print the summary of the model, we'll see the total number of parameters we have to train.

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 10, 118, 118, 8)  224
#  ibuted)
#
#  batch_normalization (BatchN  (None, 10, 118, 118, 8)  32
#  ormalization)
#
#  time_distributed_1 (TimeDis  (None, 10, 116, 116, 16)  1168
#  tributed)
#
#  batch_normalization_1 (Batc  (None, 10, 116, 116, 16)  64
#  hNormalization)
#
#  conv_lstm2d (ConvLSTM2D)    (None, 114, 114, 8)       6944
#
#  batch_normalization_2 (Batc  (None, 114, 114, 8)      32
#  hNormalization)
#
#  time_distributed_2 (TimeDis  (None, 114, 114, 64)     576
#  tributed)
#
#  batch_normalization_3 (Batc  (None, 114, 114, 64)     256
#  hNormalization)
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13,781
# Trainable params: 13,589
# Non-trainable params: 192
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the train_generator and the val_generator which will be used in .fit_generator.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, we'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                        callbacks=callbacks_list, validation_data=val_generator, 
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 1.3380 - categorical_accuracy: 0.3720
# Epoch 1: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00001-1.33804-0.37202-2.12505-0.17969.h5
# 21/21 [==============================] - 85s 4s/step - loss: 1.3380 - categorical_accuracy: 0.3720 - val_loss: 2.1250 - val_categorical_accuracy: 0.1797 - lr: 0.0100
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2183 - categorical_accuracy: 0.4628
# Epoch 2: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00002-1.21828-0.46280-1.26718-0.18750.h5
# 21/21 [==============================] - 84s 4s/step - loss: 1.2183 - categorical_accuracy: 0.4628 - val_loss: 1.2672 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0339 - categorical_accuracy: 0.5283
# Epoch 3: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00003-1.03389-0.52827-1.32236-0.22656.h5
# 21/21 [==============================] - 77s 4s/step - loss: 1.0339 - categorical_accuracy: 0.5283 - val_loss: 1.3224 - val_categorical_accuracy: 0.2266 - lr: 0.0100
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9869 - categorical_accuracy: 0.5595
# Epoch 4: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00004-0.98686-0.55952-1.26706-0.20312.h5
# 21/21 [==============================] - 84s 4s/step - loss: 0.9869 - categorical_accuracy: 0.5595 - val_loss: 1.2671 - val_categorical_accuracy: 0.2031 - lr: 0.0100
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9058 - categorical_accuracy: 0.6131
# Epoch 5: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00005-0.90579-0.61310-1.40616-0.13281.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.9058 - categorical_accuracy: 0.6131 - val_loss: 1.4062 - val_categorical_accuracy: 0.1328 - lr: 0.0100
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8486 - categorical_accuracy: 0.5982
# Epoch 6: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00006-0.84857-0.59821-1.47852-0.18750.h5
# 21/21 [==============================] - 82s 4s/step - loss: 0.8486 - categorical_accuracy: 0.5982 - val_loss: 1.4785 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 7/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8295 - categorical_accuracy: 0.6176
# Epoch 7: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00007-0.82953-0.61756-1.34602-0.16406.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.8295 - categorical_accuracy: 0.6176 - val_loss: 1.3460 - val_categorical_accuracy: 0.1641 - lr: 0.0100
# Epoch 8/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8494 - categorical_accuracy: 0.6399
# Epoch 8: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00008-0.84940-0.63988-1.91167-0.23438.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.8494 - categorical_accuracy: 0.6399 - val_loss: 1.9117 - val_categorical_accuracy: 0.2344 - lr: 0.0100
# Epoch 9/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8955 - categorical_accuracy: 0.6295
# Epoch 9: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00009-0.89545-0.62946-2.84817-0.39844.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 21/21 [==============================] - 78s 4s/step - loss: 0.8955 - categorical_accuracy: 0.6295 - val_loss: 2.8482 - val_categorical_accuracy: 0.3984 - lr: 0.0100
# Epoch 10/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7440 - categorical_accuracy: 0.6830
# Epoch 10: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00010-0.74401-0.68304-2.62161-0.10938.h5
# 21/21 [==============================] - 82s 4s/step - loss: 0.7440 - categorical_accuracy: 0.6830 - val_loss: 2.6216 - val_categorical_accuracy: 0.1094 - lr: 0.0020
# Epoch 11/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6347 - categorical_accuracy: 0.7426
# Epoch 11: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00011-0.63467-0.74256-2.67492-0.17969.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.6347 - categorical_accuracy: 0.7426 - val_loss: 2.6749 - val_categorical_accuracy: 0.1797 - lr: 0.0020
# Epoch 12/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6323 - categorical_accuracy: 0.7277
# Epoch 12: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00012-0.63233-0.72768-2.34671-0.39062.h5
# 21/21 [==============================] - 82s 4s/step - loss: 0.6323 - categorical_accuracy: 0.7277 - val_loss: 2.3467 - val_categorical_accuracy: 0.3906 - lr: 0.0020
# Epoch 13/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6019 - categorical_accuracy: 0.7560
# Epoch 13: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00013-0.60190-0.75595-2.64454-0.15625.h5
# 21/21 [==============================] - 83s 4s/step - loss: 0.6019 - categorical_accuracy: 0.7560 - val_loss: 2.6445 - val_categorical_accuracy: 0.1562 - lr: 0.0020
# Epoch 14/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5791 - categorical_accuracy: 0.7679
# Epoch 14: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00014-0.57907-0.76786-2.05303-0.39844.h5
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.001.
# 21/21 [==============================] - 78s 4s/step - loss: 0.5791 - categorical_accuracy: 0.7679 - val_loss: 2.0530 - val_categorical_accuracy: 0.3984 - lr: 0.0020
# Epoch 15/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5707 - categorical_accuracy: 0.7753
# Epoch 15: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00015-0.57065-0.77530-1.89724-0.42188.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.5707 - categorical_accuracy: 0.7753 - val_loss: 1.8972 - val_categorical_accuracy: 0.4219 - lr: 0.0010
# Epoch 16/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5739 - categorical_accuracy: 0.7589
# Epoch 16: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00016-0.57385-0.75893-1.72422-0.44531.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.5739 - categorical_accuracy: 0.7589 - val_loss: 1.7242 - val_categorical_accuracy: 0.4453 - lr: 0.0010
# Epoch 17/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5672 - categorical_accuracy: 0.7649
# Epoch 17: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00017-0.56718-0.76488-1.17027-0.54688.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.5672 - categorical_accuracy: 0.7649 - val_loss: 1.1703 - val_categorical_accuracy: 0.5469 - lr: 0.0010
# Epoch 18/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5801 - categorical_accuracy: 0.7604
# Epoch 18: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00018-0.58010-0.76042-1.08446-0.41406.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.5801 - categorical_accuracy: 0.7604 - val_loss: 1.0845 - val_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 19/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5482 - categorical_accuracy: 0.7723
# Epoch 19: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00019-0.54821-0.77232-1.07877-0.42969.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.5482 - categorical_accuracy: 0.7723 - val_loss: 1.0788 - val_categorical_accuracy: 0.4297 - lr: 0.0010
# Epoch 20/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5232 - categorical_accuracy: 0.7991
# Epoch 20: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00020-0.52316-0.79911-0.98967-0.42969.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.5232 - categorical_accuracy: 0.7991 - val_loss: 0.9897 - val_categorical_accuracy: 0.4297 - lr: 0.0010
# Epoch 21/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5533 - categorical_accuracy: 0.7604
# Epoch 21: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00021-0.55327-0.76042-0.78496-0.46875.h5
# 21/21 [==============================] - 84s 4s/step - loss: 0.5533 - categorical_accuracy: 0.7604 - val_loss: 0.7850 - val_categorical_accuracy: 0.4688 - lr: 0.0010
# Epoch 22/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5359 - categorical_accuracy: 0.7798
# Epoch 22: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00022-0.53595-0.77976-0.94375-0.46094.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.5359 - categorical_accuracy: 0.7798 - val_loss: 0.9437 - val_categorical_accuracy: 0.4609 - lr: 0.0010
# Epoch 23/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5123 - categorical_accuracy: 0.7783
# Epoch 23: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00023-0.51226-0.77827-0.72678-0.47656.h5
# 21/21 [==============================] - 82s 4s/step - loss: 0.5123 - categorical_accuracy: 0.7783 - val_loss: 0.7268 - val_categorical_accuracy: 0.4766 - lr: 0.0010
# Epoch 24/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5548 - categorical_accuracy: 0.7679
# Epoch 24: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00024-0.55482-0.76786-0.78953-0.48438.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.5548 - categorical_accuracy: 0.7679 - val_loss: 0.7895 - val_categorical_accuracy: 0.4844 - lr: 0.0010
# Epoch 25/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5746 - categorical_accuracy: 0.7649
# Epoch 25: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00025-0.57462-0.76488-0.70472-0.49219.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.5746 - categorical_accuracy: 0.7649 - val_loss: 0.7047 - val_categorical_accuracy: 0.4922 - lr: 0.0010
# Epoch 26/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5325 - categorical_accuracy: 0.7783
# Epoch 26: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00026-0.53249-0.77827-0.70247-0.75000.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.5325 - categorical_accuracy: 0.7783 - val_loss: 0.7025 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 27/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5527 - categorical_accuracy: 0.7872
# Epoch 27: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00027-0.55269-0.78720-0.50837-0.60156.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.5527 - categorical_accuracy: 0.7872 - val_loss: 0.5084 - val_categorical_accuracy: 0.6016 - lr: 0.0010
# Epoch 28/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5765 - categorical_accuracy: 0.7500
# Epoch 28: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00028-0.57646-0.75000-0.48760-0.56250.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.5765 - categorical_accuracy: 0.7500 - val_loss: 0.4876 - val_categorical_accuracy: 0.5625 - lr: 0.0010
# Epoch 29/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5643 - categorical_accuracy: 0.7664
# Epoch 29: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00029-0.56434-0.76637-0.55354-0.57031.h5
# 21/21 [==============================] - 83s 4s/step - loss: 0.5643 - categorical_accuracy: 0.7664 - val_loss: 0.5535 - val_categorical_accuracy: 0.5703 - lr: 0.0010
# Epoch 30/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5330 - categorical_accuracy: 0.7723
# Epoch 30: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00030-0.53301-0.77232-0.53093-0.60156.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.5330 - categorical_accuracy: 0.7723 - val_loss: 0.5309 - val_categorical_accuracy: 0.6016 - lr: 0.0010
# Epoch 31/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5408 - categorical_accuracy: 0.7664
# Epoch 31: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00031-0.54082-0.76637-0.92509-0.43750.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.5408 - categorical_accuracy: 0.7664 - val_loss: 0.9251 - val_categorical_accuracy: 0.4375 - lr: 0.0010
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5300 - categorical_accuracy: 0.7812
# Epoch 32: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00032-0.53004-0.78125-0.75422-0.54688.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.5300 - categorical_accuracy: 0.7812 - val_loss: 0.7542 - val_categorical_accuracy: 0.5469 - lr: 0.0010
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5030 - categorical_accuracy: 0.7798
# Epoch 33: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00033-0.50297-0.77976-0.67041-0.78906.h5
# 21/21 [==============================] - 82s 4s/step - loss: 0.5030 - categorical_accuracy: 0.7798 - val_loss: 0.6704 - val_categorical_accuracy: 0.7891 - lr: 0.0010
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5005 - categorical_accuracy: 0.7976
# Epoch 34: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00034-0.50054-0.79762-0.77412-0.53906.h5
# 21/21 [==============================] - 79s 4s/step - loss: 0.5005 - categorical_accuracy: 0.7976 - val_loss: 0.7741 - val_categorical_accuracy: 0.5391 - lr: 0.0010
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4706 - categorical_accuracy: 0.7961
# Epoch 35: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00035-0.47057-0.79613-0.69708-0.60156.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.4706 - categorical_accuracy: 0.7961 - val_loss: 0.6971 - val_categorical_accuracy: 0.6016 - lr: 0.0010
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5402 - categorical_accuracy: 0.7842
# Epoch 36: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00036-0.54015-0.78423-0.66278-0.54688.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.5402 - categorical_accuracy: 0.7842 - val_loss: 0.6628 - val_categorical_accuracy: 0.5469 - lr: 0.0010
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4896 - categorical_accuracy: 0.7857
# Epoch 37: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00037-0.48958-0.78571-0.62292-0.79688.h5
# 21/21 [==============================] - 83s 4s/step - loss: 0.4896 - categorical_accuracy: 0.7857 - val_loss: 0.6229 - val_categorical_accuracy: 0.7969 - lr: 0.0010
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5443 - categorical_accuracy: 0.7991
# Epoch 38: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00038-0.54434-0.79911-0.92420-0.52344.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.5443 - categorical_accuracy: 0.7991 - val_loss: 0.9242 - val_categorical_accuracy: 0.5234 - lr: 0.0010
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4946 - categorical_accuracy: 0.7827
# Epoch 39: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00039-0.49457-0.78274-0.54323-0.59375.h5
# 21/21 [==============================] - 83s 4s/step - loss: 0.4946 - categorical_accuracy: 0.7827 - val_loss: 0.5432 - val_categorical_accuracy: 0.5938 - lr: 0.0010
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4808 - categorical_accuracy: 0.8021
# Epoch 40: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00040-0.48082-0.80208-0.79072-0.60156.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.4808 - categorical_accuracy: 0.8021 - val_loss: 0.7907 - val_categorical_accuracy: 0.6016 - lr: 0.0010
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4868 - categorical_accuracy: 0.7961
# Epoch 41: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00041-0.48685-0.79613-0.60622-0.78906.h5
# 21/21 [==============================] - 83s 4s/step - loss: 0.4868 - categorical_accuracy: 0.7961 - val_loss: 0.6062 - val_categorical_accuracy: 0.7891 - lr: 0.0010
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5435 - categorical_accuracy: 0.7857
# Epoch 42: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00042-0.54351-0.78571-0.81932-0.50000.h5
# 21/21 [==============================] - 83s 4s/step - loss: 0.5435 - categorical_accuracy: 0.7857 - val_loss: 0.8193 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4873 - categorical_accuracy: 0.7991
# Epoch 43: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00043-0.48725-0.79911-0.69770-0.75781.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.4873 - categorical_accuracy: 0.7991 - val_loss: 0.6977 - val_categorical_accuracy: 0.7578 - lr: 0.0010
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4407 - categorical_accuracy: 0.8170
# Epoch 44: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00044-0.44075-0.81696-0.54615-0.63281.h5
# 21/21 [==============================] - 84s 4s/step - loss: 0.4407 - categorical_accuracy: 0.8170 - val_loss: 0.5462 - val_categorical_accuracy: 0.6328 - lr: 0.0010
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4642 - categorical_accuracy: 0.7961
# Epoch 45: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00045-0.46420-0.79613-0.67304-0.59375.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.4642 - categorical_accuracy: 0.7961 - val_loss: 0.6730 - val_categorical_accuracy: 0.5938 - lr: 0.0010
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4467 - categorical_accuracy: 0.8199
# Epoch 46: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00046-0.44668-0.81994-0.80004-0.57031.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.4467 - categorical_accuracy: 0.8199 - val_loss: 0.8000 - val_categorical_accuracy: 0.5703 - lr: 0.0010
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5755 - categorical_accuracy: 0.7619
# Epoch 47: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00047-0.57547-0.76190-0.91515-0.50000.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.5755 - categorical_accuracy: 0.7619 - val_loss: 0.9152 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5067 - categorical_accuracy: 0.8006
# Epoch 48: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00048-0.50670-0.80060-0.82501-0.75000.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.5067 - categorical_accuracy: 0.8006 - val_loss: 0.8250 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4599 - categorical_accuracy: 0.8155
# Epoch 49: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00049-0.45993-0.81548-0.69465-0.78125.h5
# 21/21 [==============================] - 78s 4s/step - loss: 0.4599 - categorical_accuracy: 0.8155 - val_loss: 0.6947 - val_categorical_accuracy: 0.7812 - lr: 0.0010
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4735 - categorical_accuracy: 0.8036
# Epoch 50: saving model to model_init_exp_16_2023-03-1911_32_40.752220/model-00050-0.47347-0.80357-0.96593-0.46094.h5
# 21/21 [==============================] - 77s 4s/step - loss: 0.4735 - categorical_accuracy: 0.8036 - val_loss: 0.9659 - val_categorical_accuracy: 0.4609 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
